# %%
# %load_ext autoreload
# %autoreload 2

from IPython.core.display import display, HTML
display(HTML("<style>.container { width:80% !important; }</style>"))
import numpy as np; np.set_printoptions(linewidth=110);
import pandas as pd
# tell pandas to show all columns when we display a DataFrame
pd.set_option("display.max_columns", None)

# first we need a bit of import boilerplate
import os
import sys
from sys import platform
if platform == 'win32':
    sys.path.append('D:/Brain_Network/Code/')
    manifest_path = 'D:/Brain_Network/Data/Allen_Institute_Dataset/manifest.json'
    project_dir = 'D:/Brain_Network/'
elif platform =='darwin':
    sys.path.append('/Users/chenyu/Workspace/Brain_Network/Code/')
    manifest_path = '/Users/chenyu/Workspace/Brain_Network/Data/Allen_Institute_Dataset/manifest.json'
    project_dir = '/Users/chenyu/Workspace/Brain_Network/'
elif platform == 'linux':
    project_dir = '/v/global/user/c/ch/chenyu36/workspace_vi/AllenSDK/'
    sys.path.append('/v/global/user/c/ch/chenyu36/workspace_vi/AllenSDK/jitter/')
    manifest_path = '/v/global/user/c/ch/chenyu36/workspace_vi/AllenSDK/Data/Allen_Institute_Dataset/manifest.json'
else:
    print('Add new computer system settings.')

import itertools
import matplotlib.pyplot as plt
import seaborn
import scipy
import scipy.io as sio
from scipy.ndimage.filters import gaussian_filter
import seaborn
from tqdm import tqdm
from tqdm.notebook import trange
import time
from datetime import datetime
import joblib
from joblib import Parallel, delayed

from allensdk.brain_observatory.ecephys.ecephys_project_cache import EcephysProjectCache
from allensdk.brain_observatory.ecephys.ecephys_session import EcephysSession

import data_visualizer
import data_model
import fine_time_coupling_model
import smoothing_spline
import util
import hierarchical_sampling_model
import hierarchical_model_generator
import jitter
# Out:
# <style>.container { width:80% !important; }</style>

# %%
import allensdk
import pandas
import h5py
import pynwb
import hdmf
import matplotlib
print('allensdk', allensdk.__version__)
print('pandas', pandas.__version__)
print('h5py', h5py.__version__)
print('pynwb', pynwb.__version__)
print('hdmf', hdmf.__version__)
print('matplotlib', matplotlib.__version__)
# Out:
# allensdk 2.2.0
# pandas 1.3.5
# h5py 2.8.0
# pynwb 1.4.0
# hdmf 2.2.0
# matplotlib 3.4.1

# %% [markdown]
# # Neuropixels data. <a name='data'></a>

# %%
cache = EcephysProjectCache.from_warehouse(manifest=manifest_path)
# Out:
# Download time: 720000

# %%
session_id = 798911424  #  791319847 798911424  799864342
session = cache.get_session_data(session_id)

# %% [markdown]
# ### Neurons Selection

# %%
# %%time
# Check basic statistics of all probes.
probes = ['probeA', 'probeB', 'probeC', 'probeD', 'probeE', 'probeF']
selected_units = session.units[
    session.units['ecephys_structure_acronym'].isin(util.VISUAL_AREA) &
    session.units['probe_description'].isin(probes)]
display(selected_units['probe_description'].value_counts())
display(selected_units['probe_description'].count())
display(selected_units.groupby(['probe_description', 'ecephys_structure_acronym']).last())

# Then select subset of probes.
probes = ['probeA', 'probeC', 'probeD', 'probeE', 'probeF']
selected_units = session.units[
    session.units['ecephys_structure_acronym'].isin(util.VISUAL_AREA) &
    session.units['probe_description'].isin(probes)]
print('final selected probes', probes)

# V1, LM, RL, IP, AL, PM, AM (needs manual sort for different anymals.)
area_hierarchy = ['probeC', 'probeD', 'probeF', 'probeE', 'probeA']  # 798911424
# Out:
# probeC    94
# probeE    89
# probeA    78
# probeD    78
# probeB    57
# probeF    47
# Name: probe_description, dtype: int64
# 443
#                                               L_ratio  presence_ratio  \
# probe_description ecephys_structure_acronym
# probeA            VISam                      0.015568            0.99
# probeB            VISam                      0.009419            0.99
# probeC            VISp                       0.042912            0.99
# probeD            VISl                       0.014502            0.99
# probeE            VISal                      0.020613            0.99
# probeF            VISrl                      0.000917            0.99
#
#                                              isolation_distance       snr  \
# probe_description ecephys_structure_acronym
# probeA            VISam                               56.873778  2.217387
# probeB            VISam                              535.883528  2.231816
# probeC            VISp                                37.973009  1.832974
# probeD            VISl                                56.397459  2.002475
# probeE            VISal                               66.193342  1.952424
# probeF            VISrl                               64.113833  4.906060
#
#                                              waveform_duration  nn_miss_rate  \
# probe_description ecephys_structure_acronym
# probeA            VISam                               0.714238      0.004750
# probeB            VISam                               0.233501      0.054688
# probeC            VISp                                0.755444      0.006829
# probeD            VISl                                1.263652      0.000921
# probeE            VISal                               0.590620      0.010801
# probeF            VISrl                               0.700503      0.000371
#
#                                              waveform_recovery_slope  \
# probe_description ecephys_structure_acronym
# probeA            VISam                                    -0.015566
# probeB            VISam                                    -0.034283
# probeC            VISp                                     -0.018379
# probeD            VISl                                     -0.065126
# probeE            VISal                                    -0.022824
# probeF            VISrl                                    -0.023393
#
#                                              waveform_velocity_below  \
# probe_description ecephys_structure_acronym
# probeA            VISam                                     0.755444
# probeB            VISam                                     0.327032
# probeC            VISp                                      0.686767
# probeD            VISl                                      0.206030
# probeE            VISal                                    -2.197655
# probeF            VISrl                                     0.000000
#
#                                              firing_rate  cluster_id  \
# probe_description ecephys_structure_acronym
# probeA            VISam                         2.330244         392
# probeB            VISam                        17.989545         287
# probeC            VISp                          1.047711         420
# probeD            VISl                          1.574157         393
# probeE            VISal                         3.977016         429
# probeF            VISrl                         0.351025         339
#
#                                              local_index_unit  \
# probe_description ecephys_structure_acronym
# probeA            VISam                                   385
# probeB            VISam                                   279
# probeC            VISp                                    400
# probeD            VISl                                    377
# probeE            VISal                                   425
# probeF            VISrl                                   335
#
#                                              waveform_repolarization_slope  \
# probe_description ecephys_structure_acronym
# probeA            VISam                                           0.182642
# probeB            VISam                                           0.239873
# probeC            VISp                                            0.131790
# probeD            VISl                                            0.010473
# probeE            VISal                                           0.126370
# probeF            VISrl                                           0.478545
#
#                                              waveform_halfwidth  max_drift  \
# probe_description ecephys_structure_acronym
# probeA            VISam                                0.247236      40.75
# probeB            VISam                                0.178559      25.63
# probeC            VISp                                 0.247236      35.20
# probeD            VISl                                 0.192295      23.77
# probeE            VISal                                0.178559      49.66
# probeF            VISrl                                0.192295      19.29
#
#                                              waveform_PT_ratio  \
# probe_description ecephys_structure_acronym
# probeA            VISam                               0.374745
# probeB            VISam                               0.191810
# probeC            VISp                                0.487796
# probeD            VISl                               13.146540
# probeE            VISal                               0.434691
# probeF            VISrl                               0.318873
#
#                                              cumulative_drift  \
# probe_description ecephys_structure_acronym
# probeA            VISam                                459.38
# probeB            VISam                                182.65
# probeC            VISp                                 427.14
# probeD            VISl                                 232.75
# probeE            VISal                                183.79
# probeF            VISrl                                111.89
#
#                                              waveform_spread  \
# probe_description ecephys_structure_acronym
# probeA            VISam                                 50.0
# probeB            VISam                                 90.0
# probeC            VISp                                  60.0
# probeD            VISl                                  60.0
# probeE            VISal                                 80.0
# probeF            VISrl                                 50.0
#
#                                              amplitude_cutoff   d_prime  \
# probe_description ecephys_structure_acronym
# probeA            VISam                              0.022298  4.275154
# probeB            VISam                              0.009865  4.790931
# probeC            VISp                               0.021331  2.867965
# probeD            VISl                               0.010090  5.281608
# probeE            VISal                              0.014189  3.474211
# probeF            VISrl                              0.003946  5.315956
#
#                                              waveform_amplitude  \
# probe_description ecephys_structure_acronym
# probeA            VISam                               64.803765
# probeB            VISam                               53.481090
# probeC            VISp                                50.750505
# probeD            VISl                                51.905490
# probeE            VISal                               43.093050
# probeF            VISrl                              152.919000
#
#                                              peak_channel_id  \
# probe_description ecephys_structure_acronym
# probeA            VISam                            849855994
# probeB            VISam                            849854722
# probeC            VISp                             849853312
# probeD            VISl                             849851976
# probeE            VISal                            849850704
# probeF            VISrl                            849849466
#
#                                              silhouette_score  nn_hit_rate  \
# probe_description ecephys_structure_acronym
# probeA            VISam                              0.125534     0.963333
# probeB            VISam                              0.101824     0.997333
# probeC            VISp                               0.079066     0.575630
# probeD            VISl                               0.171867     0.962000
# probeE            VISal                              0.039108     0.972000
# probeF            VISrl                              0.342093     0.984252
#
#                                              waveform_velocity_above  \
# probe_description ecephys_structure_acronym
# probeA            VISam                                     2.060302
# probeB            VISam                                     0.686767
# probeC            VISp                                      1.030151
# probeD            VISl                                      0.000000
# probeE            VISal                                     0.137353
# probeF            VISrl                                     1.030151
#
#                                              isi_violations    c50_dg  \
# probe_description ecephys_structure_acronym
# probeA            VISam                            0.125646  0.060341
# probeB            VISam                            0.012760  0.124518
# probeC            VISp                             0.294413  1.065773
# probeD            VISl                             0.202876  0.565196
# probeE            VISal                            0.131684  1.061494
# probeF            VISrl                            0.000000  0.017557
#
#                                              area_rf   fano_dg   fano_fl  \
# probe_description ecephys_structure_acronym
# probeA            VISam                        700.0  3.257075  0.826667
# probeB            VISam                        300.0  1.427952  1.081905
# probeC            VISp                         900.0  3.230108  1.253333
# probeD            VISl                         300.0  3.110256  0.911667
# probeE            VISal                        800.0  7.006393  1.326275
# probeF            VISrl                          0.0  2.133333  0.933333
#
#                                               fano_ns   fano_rf   fano_sg  \
# probe_description ecephys_structure_acronym
# probeA            VISam                      0.756547  1.308333  0.322535
# probeB            VISam                      0.741379  0.708527  1.058712
# probeC            VISp                       1.165714  1.911111  0.940000
# probeD            VISl                       0.628213  3.533333  1.270639
# probeE            VISal                      0.591348  0.873810  0.780243
# probeF            VISrl                      1.403077  3.733333  0.534439
#
#                                              f1_f0_dg  g_dsi_dg  g_osi_dg  \
# probe_description ecephys_structure_acronym
# probeA            VISam                      0.342330  0.025033  0.340267
# probeB            VISam                      0.182809  0.045579  0.082039
# probeC            VISp                       0.929324  0.091061  0.228532
# probeD            VISl                       1.575176  0.294153  0.941154
# probeE            VISal                      0.979135  0.179284  0.050768
# probeF            VISrl                      1.593175  0.281483  0.148936
#
#                                              g_osi_sg  azimuth_rf  mod_idx_dg  \
# probe_description ecephys_structure_acronym
# probeA            VISam                      0.625045      82.857    1.248681
# probeB            VISam                      0.072583      40.000    0.740204
# probeC            VISp                       0.396523      44.444    4.818274
# probeD            VISl                       0.674843      13.333    0.096218
# probeE            VISal                      0.119111      81.250    0.771620
# probeF            VISrl                      0.634606      48.889    1.262807
#
#                                              p_value_rf  pref_sf_sg  \
# probe_description ecephys_structure_acronym
# probeA            VISam                           0.000        0.04
# probeB            VISam                           0.000        0.04
# probeC            VISp                            0.000        0.32
# probeD            VISl                            0.007        0.08
# probeE            VISal                           0.000        0.02
# probeF            VISrl                           0.495        0.02
#
#                                              pref_tf_dg  run_mod_dg  \
# probe_description ecephys_structure_acronym
# probeA            VISam                             1.0    0.027656
# probeB            VISam                             2.0    0.140547
# probeC            VISp                              2.0   -0.135593
# probeD            VISl                              1.0    0.676190
# probeE            VISal                             1.0    0.546778
# probeF            VISrl                             2.0   -0.625000
#
#                                              run_mod_fl  run_mod_ns  \
# probe_description ecephys_structure_acronym
# probeA            VISam                        0.618182    0.309144
# probeB            VISam                        0.409060    0.221643
# probeC            VISp                        -0.684783    0.570520
# probeD            VISl                         0.278997    0.238298
# probeE            VISal                       -0.369565   -0.287250
# probeF            VISrl                       -0.842391   -0.466667
#
#                                              run_mod_rf  run_mod_sg  \
# probe_description ecephys_structure_acronym
# probeA            VISam                        0.611111    0.180976
# probeB            VISam                        0.305556    0.092159
# probeC            VISp                        -1.000000    0.558036
# probeD            VISl                         0.393939    0.573171
# probeE            VISal                       -0.500000    0.245283
# probeF            VISrl                       -0.421053    0.469231
#
#                                              pref_ori_dg  pref_ori_sg  \
# probe_description ecephys_structure_acronym
# probeA            VISam                              0.0          0.0
# probeB            VISam                              0.0        150.0
# probeC            VISp                               0.0          0.0
# probeD            VISl                               0.0          0.0
# probeE            VISal                            225.0        120.0
# probeF            VISrl                              0.0         30.0
#
#                                              run_pval_dg  run_pval_fl  \
# probe_description ecephys_structure_acronym
# probeA            VISam                         0.876909     0.082969
# probeB            VISam                         0.007933     0.000027
# probeC            VISp                          0.693759     0.286903
# probeD            VISl                          0.064443     0.509116
# probeE            VISal                         0.666265     0.065274
# probeF            VISrl                         0.251204     0.099829
#
#                                              run_pval_ns  run_pval_rf  \
# probe_description ecephys_structure_acronym
# probeA            VISam                         0.000228     0.216980
# probeB            VISam                         0.001777     0.035865
# probeC            VISp                          0.005894     0.009152
# probeD            VISl                          0.000314     0.087377
# probeE            VISal                         0.009331     0.495045
# probeF            VISrl                         0.300753     0.032662
#
#                                               run_pval_sg  elevation_rf  \
# probe_description ecephys_structure_acronym
# probeA            VISam                      7.776317e-04        10.000
# probeB            VISam                      3.235461e-01        50.000
# probeC            VISp                       2.096170e-04        14.444
# probeD            VISl                       7.452588e-08        13.333
# probeE            VISal                      2.689656e-01        11.250
# probeF            VISrl                      1.696496e-02        -6.667
#
#                                              pref_image_ns  pref_phase_sg  \
# probe_description ecephys_structure_acronym
# probeA            VISam                               4992           0.00
# probeB            VISam                               4992           0.00
# probeC            VISp                                4984           0.25
# probeD            VISl                                4933           0.75
# probeE            VISal                               4929           0.75
# probeF            VISrl                               4973           0.00
#
#                                              firing_rate_dg  firing_rate_fl  \
# probe_description ecephys_structure_acronym
# probeA            VISam                            3.965416        0.586179
# probeB            VISam                           18.205227       18.144899
# probeC            VISp                             0.822312        0.186511
# probeD            VISl                             0.418834        0.000000
# probeE            VISal                            3.187583        4.236474
# probeF            VISrl                            0.167322        0.186511
#
#                                              firing_rate_ns  firing_rate_rf  \
# probe_description ecephys_structure_acronym
# probeA            VISam                            2.079605        0.878294
# probeB            VISam                           20.948526        8.370656
# probeC            VISp                             1.217805        0.678731
# probeD            VISl                             5.952667        0.149124
# probeE            VISal                            5.080120        4.387083
# probeF            VISrl                            0.500422        0.049342
#
#                                              firing_rate_sg  on_off_ratio_fl  \
# probe_description ecephys_structure_acronym
# probeA            VISam                            5.096403              NaN
# probeB            VISam                           24.441554              NaN
# probeC            VISp                             1.402826              NaN
# probeD            VISl                             3.299906              NaN
# probeE            VISal                            3.001489              NaN
# probeF            VISrl                            0.484928              NaN
#
#                                              time_to_peak_ns  \
# probe_description ecephys_structure_acronym
# probeA            VISam                               0.1165
# probeB            VISam                               0.1225
# probeC            VISp                                0.0915
# probeD            VISl                                0.1025
# probeE            VISal                               0.0705
# probeF            VISrl                               0.1995
#
#                                              pref_sf_multi_sg  \
# probe_description ecephys_structure_acronym
# probeA            VISam                                 False
# probeB            VISam                                 False
# probeC            VISp                                  False
# probeD            VISl                                  False
# probeE            VISal                                 False
# probeF            VISrl                                 False
#
#                                              pref_tf_multi_dg  \
# probe_description ecephys_structure_acronym
# probeA            VISam                                 False
# probeB            VISam                                 False
# probeC            VISp                                  False
# probeD            VISl                                  False
# probeE            VISal                                 False
# probeF            VISrl                                 False
#
#                                              pref_ori_multi_dg  \
# probe_description ecephys_structure_acronym
# probeA            VISam                                  False
# probeB            VISam                                  False
# probeC            VISp                                   False
# probeD            VISl                                   False
# probeE            VISal                                  False
# probeF            VISrl                                  False
#
#                                              pref_ori_multi_sg  \
# probe_description ecephys_structure_acronym
# probeA            VISam                                  False
# probeB            VISam                                  False
# probeC            VISp                                   False
# probeD            VISl                                   False
# probeE            VISal                                  False
# probeF            VISrl                                  False
#
#                                              pref_phase_multi_sg  \
# probe_description ecephys_structure_acronym
# probeA            VISam                                    False
# probeB            VISam                                    False
# probeC            VISp                                     False
# probeD            VISl                                     False
# probeE            VISal                                    False
# probeF            VISrl                                    False
#
#                                              image_selectivity_ns  \
# probe_description ecephys_structure_acronym
# probeA            VISam                                  0.830508
# probeB            VISam                                  0.272542
# probeC            VISp                                   0.504254
# probeD            VISl                                   0.669593
# probeE            VISal                                  0.398390
# probeF            VISrl                                  0.516712
#
#                                              pref_image_multi_ns  \
# probe_description ecephys_structure_acronym
# probeA            VISam                                    False
# probeB            VISam                                    False
# probeC            VISp                                     False
# probeD            VISl                                     False
# probeE            VISal                                    False
# probeF            VISrl                                    False
#
#                                              lifetime_sparseness_dg  \
# probe_description ecephys_structure_acronym
# probeA            VISam                                    0.488876
# probeB            VISam                                    0.021480
# probeC            VISp                                     0.373882
# probeD            VISl                                     0.707620
# probeE            VISal                                    0.151906
# probeF            VISrl                                    0.370016
#
#                                              lifetime_sparseness_fl  \
# probe_description ecephys_structure_acronym
# probeA            VISam                                    0.064000
# probeB            VISam                                    0.001556
# probeC            VISp                                     0.675676
# probeD            VISl                                     0.101124
# probeE            VISal                                    0.148319
# probeF            VISrl                                    0.310345
#
#                                              lifetime_sparseness_ns  \
# probe_description ecephys_structure_acronym
# probeA            VISam                                    0.695607
# probeB            VISam                                    0.031615
# probeC            VISp                                     0.320768
# probeD            VISl                                     0.553107
# probeE            VISal                                    0.086482
# probeF            VISrl                                    0.417147
#
#                                              lifetime_sparseness_rf  \
# probe_description ecephys_structure_acronym
# probeA            VISam                                    0.460287
# probeB            VISam                                    0.167023
# probeC            VISp                                     0.586041
# probeD            VISl                                     0.849416
# probeE            VISal                                    0.282937
# probeF            VISrl                                    0.875397
#
#                                              lifetime_sparseness_sg  \
# probe_description ecephys_structure_acronym
# probeA            VISam                                    0.631725
# probeB            VISam                                    0.025828
# probeC            VISp                                     0.418974
# probeD            VISl                                     0.528138
# probeE            VISal                                    0.123338
# probeF            VISrl                                    0.424824
#
#                                              probe_vertical_position  \
# probe_description ecephys_structure_acronym
# probeA            VISam                                         2700
# probeB            VISam                                         2560
# probeC            VISp                                          2360
# probeD            VISl                                          2120
# probeE            VISal                                         2880
# probeF            VISrl                                         3260
#
#                                              probe_horizontal_position  \
# probe_description ecephys_structure_acronym
# probeA            VISam                                             11
# probeB            VISam                                             27
# probeC            VISp                                              59
# probeD            VISl                                              27
# probeE            VISal                                             27
# probeF            VISrl                                             11
#
#                                               probe_id  channel_local_index  \
# probe_description ecephys_structure_acronym
# probeA            VISam                      800036196                  269
# probeB            VISam                      800036198                  255
# probeC            VISp                       800036200                  234
# probeD            VISl                       800036202                  211
# probeE            VISal                      800036204                  287
# probeF            VISrl                      800036206                  325
#
#                                              ecephys_structure_id  \
# probe_description ecephys_structure_acronym
# probeA            VISam                                     394.0
# probeB            VISam                                     394.0
# probeC            VISp                                      385.0
# probeD            VISl                                      409.0
# probeE            VISal                                     402.0
# probeF            VISrl                                     417.0
#
#                                              anterior_posterior_ccf_coordinate  \
# probe_description ecephys_structure_acronym
# probeA            VISam                                                 7613.0
# probeB            VISam                                                 7943.0
# probeC            VISp                                                  9130.0
# probeD            VISl                                                  8581.0
# probeE            VISal                                                 8191.0
# probeF            VISrl                                                 7260.0
#
#                                              dorsal_ventral_ccf_coordinate  \
# probe_description ecephys_structure_acronym
# probeA            VISam                                              481.0
# probeB            VISam                                              476.0
# probeC            VISp                                               827.0
# probeD            VISl                                              1915.0
# probeE            VISal                                             1806.0
# probeF            VISrl                                             1106.0
#
#                                              left_right_ccf_coordinate  \
# probe_description ecephys_structure_acronym
# probeA            VISam                                         7559.0
# probeB            VISam                                         7422.0
# probeC            VISp                                          8239.0
# probeD            VISl                                          9913.0
# probeE            VISal                                         9911.0
# probeF            VISrl                                         8973.0
#
#                                                             location  \
# probe_description ecephys_structure_acronym
# probeA            VISam                      See electrode locations
# probeB            VISam                      See electrode locations
# probeC            VISp                       See electrode locations
# probeD            VISl                       See electrode locations
# probeE            VISal                      See electrode locations
# probeF            VISrl                      See electrode locations
#
#                                              probe_sampling_rate  \
# probe_description ecephys_structure_acronym
# probeA            VISam                             29999.965974
# probeB            VISam                             29999.917201
# probeC            VISp                              29999.996048
# probeD            VISl                              29999.919900
# probeE            VISal                             29999.999422
# probeF            VISrl                             30000.038460
#
#                                              probe_lfp_sampling_rate  \
# probe_description ecephys_structure_acronym
# probeA            VISam                                  1249.998582
# probeB            VISam                                  1249.996550
# probeC            VISp                                   1249.999835
# probeD            VISl                                   1249.996662
# probeE            VISal                                  1249.999976
# probeF            VISrl                                  1250.001602
#
#                                              probe_has_lfp_data
# probe_description ecephys_structure_acronym
# probeA            VISam                                    True
# probeB            VISam                                    True
# probeC            VISp                                     True
# probeD            VISl                                     True
# probeE            VISal                                    True
# probeF            VISrl                                    True
# final selected probes ['probeA', 'probeC', 'probeD', 'probeE', 'probeF']
# Wall time: 28.6 s

# %% [markdown]
# #### Fine Time Coupling Model

# %%
model = fine_time_coupling_model.FineTimeCouplingModel(session)
jittertool = jitter.JitterTool()

# %% [markdown]
# ## Trials Selection

# %%
# condition_ids = [251, 255, 261, 270, 278]  # x5  7913
# condition_ids = [251, 255, 261, 270, 278, 284] # x6  7913
# condition_ids = [278, 270, 255, 253, 262, 251, 258, 246, 263, 275, 247, 273]  # x12  7913

# condition_ids = [275, 268, 270, 284, 274, 249, 263, 261, 278, 267, 280, 256, 260, 257, 281]  # x15 7989
# condition_ids = [275, 246, 268, 270, 284, 274, 249, 263, 265, 261, 286, 258, 278, 267, 280, 256, 260, 257, 281]  # x19  7989
# condition_ids = [268, 270, 284, 274, 249, 261, 278, 280, 256, 260, 257, 281]  # x12 7989
# condition_ids = [270, 274, 249, 265, 261, 286, 258, 278, 280, 260, 257], all 4, 8 Hz

# %%
condition_ids = [270, 274, 249, 265, 261, 286, 258, 278, 280, 260, 257]

stimulus_table = session.get_stimulus_table(['drifting_gratings'])
trials_df = stimulus_table[stimulus_table['stimulus_condition_id'].isin(condition_ids)]
all_trials_indices = trials_df.index.values
trials_groups = trials_df.groupby('stimulus_condition_id')
all_condition_ids = list(trials_groups.groups.keys())
model.print_conditions(trials_groups)
# Out:
# 0  249 temp freq [8.0] orient [90.0] contrast [0.8] [ 3801  3810  3828  3911  3964 31002 31054 31055 31178 49257 49317 49341 49365 49395 49430]
# 1  257 temp freq [8.0] orient [315.0] contrast [0.8] [ 3813  3822  3870  3876  3932  3936  3987 31022 31027 31075 31171 49215 49217 49368 49370]
# 2  258 temp freq [4.0] orient [225.0] contrast [0.8] [ 3814  3895  3922  3967  3986  3997 31043 31151 31152 31175 31196 49251 49282 49340 49414]
# 3  260 temp freq [4.0] orient [315.0] contrast [0.8] [ 3816  3888  3930  3943  3948 31028 31033 31190 49263 49266 49320 49364 49410 49411 49428]
# 4  261 temp freq [8.0] orient [135.0] contrast [0.8] [ 3817  3826  3875  3928 31020 31053 31129 31161 31162 49230 49254 49268 49275 49313 49407]
# 5  265 temp freq [4.0] orient [135.0] contrast [0.8] [ 3824  3848  3880  3920  3953  3955  3960  3968  3973  3992 31039 31093 49232 49339 49383]
# 6  270 temp freq [8.0] orient [45.0] contrast [0.8] [ 3835  3898  3914  3934 31062 31104 31114 49250 49274 49281 49286 49304 49322 49415 49422]
# 7  274 temp freq [4.0] orient [90.0] contrast [0.8] [ 3844  3862  3897  3996 31096 31148 31156 31167 31184 31185 49349 49361 49367 49400 49420]
# 8  278 temp freq [8.0] orient [225.0] contrast [0.8] [ 3866  3878  3925  3937  3984 31142 31159 31174 31194 49290 49307 49374 49390 49401 49418]
# 9  280 temp freq [8.0] orient [270.0] contrast [0.8] [ 3872  3900  3905  3946  3956  3980 31021 31046 31064 31080 31173 31182 31188 49211 49225]
# 10  286 temp freq [8.0] orient [180.0] contrast [0.8] [ 3933  3949  3962 31154 31165 31177 31187 31199 49226 49228 49240 49280 49328 49332 49405]
# total num trials: 165

# %% [markdown]
# ## Spike Trains

# %%
# %%time
trial_window = [0.4, 2.0]

# dt=0.002
# spike_train_time_line = np.arange(trial_time_window[0], trial_time_window[1], dt)
# spike_trains = model.get_trial_metric_per_unit_per_trial(
#     stimulus_presentation_ids=all_trials_indices,
#     unit_ids=selected_units.index.values,
#     trial_time_window=trial_time_window,
#     metric_type='spike_trains', dt=dt)
# spike_counts = model.get_trial_metric_per_unit_per_trial(
#         stimulus_presentation_ids=all_trials_indices,
#         unit_ids=selected_units.index.values,
#         trial_time_window=trial_time_window,
#         metric_type='count', empty_fill=0)
spike_times = model.get_trial_metric_per_unit_per_trial(
        stimulus_presentation_ids=all_trials_indices,
        unit_ids=selected_units.index.values,
        trial_time_window=trial_window,
        metric_type='spike_times')
# Out:
# Wall time: 1min 47s

# %%
# display(spike_trains.shape)
# display(spike_trains.iloc[0,0].shape)
display(spike_times.shape)
# display(spike_times.head())
# Out:
# (386, 165)

# %% [markdown]
# # Fit individual filter + raw filter clustering.

# %%
model = fine_time_coupling_model.FineTimeCouplingModel(session)
model.initial_step(None, spike_times, selected_units, trials_groups, trial_window,
                   probes=['probeA', 'probeC', 'probeD', 'probeE', 'probeF'], num_areas=5, verbose=False)
# Out:
# conditions: [(0, 249), (1, 257), (2, 258), (3, 260), (4, 261), (5, 265), (6, 270), (7, 274), (8, 278), (9, 280), (10, 286)]

# %%
# a = stimulus_table['stimulus_condition_id'].unique(); b = np.setdiff1d(a,select_condition_ids)
# [247, 248, 250, 251, 252, 253, 254, 255, 259, 262, 264, 266, 269, 271, 272, 276, 277, 279, 282, 283, 285]
condition_ids = [270, 274, 249, 265, 261, 286, 258, 278, 280, 260, 257]

stimulus_table = session.get_stimulus_table(['drifting_gratings'])
trials_df = stimulus_table[stimulus_table['stimulus_condition_id'].isin(condition_ids)]
selected_trial_ids = trials_df.index.values
print(selected_trial_ids)
# Out:
# [ 3801  3810  3813  3814  3816  3817  3822  3824  3826  3828  3835  3844  3848  3862  3866  3870  3872  3875
#   3876  3878  3880  3888  3895  3897  3898  3900  3905  3911  3914  3920  3922  3925  3928  3930  3932  3933
#   3934  3936  3937  3943  3946  3948  3949  3953  3955  3956  3960  3962  3964  3967  3968  3973  3980  3984
#   3986  3987  3992  3996  3997 31002 31020 31021 31022 31027 31028 31033 31039 31043 31046 31053 31054 31055
#  31062 31064 31075 31080 31093 31096 31104 31114 31129 31142 31148 31151 31152 31154 31156 31159 31161 31162
#  31165 31167 31171 31173 31174 31175 31177 31178 31182 31184 31185 31187 31188 31190 31194 31196 31199 49211
#  49215 49217 49225 49226 49228 49230 49232 49240 49250 49251 49254 49257 49263 49266 49268 49274 49275 49280
#  49281 49282 49286 49290 49304 49307 49313 49317 49320 49322 49328 49332 49339 49340 49341 49349 49361 49364
#  49365 49367 49368 49370 49374 49383 49390 49395 49400 49401 49405 49407 49410 49411 49414 49415 49418 49420
#  49422 49428 49430]

# %% [markdown]
# ### Between probes.

# %%
active_firing_rate_quantile_threshold = 0.8
active_units = model.get_active_units(active_firing_rate_quantile_threshold, group_type='probe', verbose=True)

# probe_pair = ('probeC', 'probeD')
# neuron_pairs = model.construct_unit_pairs(active_units, pair_type='between_probe', probe_pairs=[probe_pair], verbose=True)
# filter_membership = model.init_filter_membership(neuron_pairs, trial_ids=selected_trial_ids, random_val=True)

probe_pairs = itertools.permutations(['probeA', 'probeC', 'probeD', 'probeE', 'probeF'], 2)
neuron_pairs = model.construct_unit_pairs(active_units, pair_type='between_probe', probe_pairs=probe_pairs, verbose=True)
filter_membership = model.init_filter_membership(neuron_pairs, trial_ids=selected_trial_ids, random_val=True)

# timestamp = datetime.now().strftime('%d_%m_%Y_%H%M%S')
# output_file = project_dir + f'Output/jitter/coupling_network/membership_{probe_pair[0]}_to_{probe_pair[1]}_{timestamp}.parquet'
# filter_membership.to_parquet(output_file)
# Out:
# area paris [('probeA', 'probeC'), ('probeA', 'probeD'), ('probeA', 'probeE'), ('probeA', 'probeF'), ('probeC', 'probeA'), ('probeC', 'probeD'), ('probeC', 'probeE'), ('probeC', 'probeF'), ('probeD', 'probeA'), ('probeD', 'probeC'), ('probeD', 'probeE'), ('probeD', 'probeF'), ('probeE', 'probeA'), ('probeE', 'probeC'), ('probeE', 'probeD'), ('probeE', 'probeF'), ('probeF', 'probeA'), ('probeF', 'probeC'), ('probeF', 'probeD'), ('probeF', 'probeE')]
# num_pairs: 4944

# %% [markdown]
# #### Select the smoothing kernel width using plug-in estimator (with sub-sampling).

# %%
kernel_width_grid = np.arange(50, 125, 5) / 1000
_,_,optimal_kernel_width = model.estimate_nuisance_kernel_width_together(filter_membership, batch_size=2000, kernel_width_grid=kernel_width_grid)
# Out:
# 100%|███████████████████████████████████████████████████████████████| 15/15 [00:17<00:00,  1.18s/it]
# optimal kernel width  115.0

# %%
# model_par = {'filter_type': 'bspline', 'num_knots': 8, 'knot_space_par': 0.05, 'filter_length': 0.05, 'num_tail_drop': 1,
#              'append_nuisance': ['const', 'gaussian_kernel'], 'kernel_width': 0.1,
#              'const_offset': 0, 'learning_rate': 0.9, 'max_num_itrs': 60, 'epsilon': 1e-5}

model_par = {'filter_type': 'square', 'filter_length': 0.04,
             'append_nuisance': ['const', 'gaussian_kernel'], 'kernel_width': 0.075,
             'const_offset': 0, 'learning_rate': 0.9, 'max_num_itrs': 60, 'epsilon': 1e-5}

model_list = model.pairwise_bivariate_regression(filter_membership, model_par, verbose=False)
# model_list = model.pairwise_bivariate_regression(filter_membership, model_par, verbose=False, parallel=True, num_threads=6)

print('num_models', len(model_list))
timestamp = datetime.now().strftime('%d_%m_%Y_%H%M%S')
model_file = project_dir + f'Output/jitter/coupling_network/model_list_{probe_pair[0]}_to_{probe_pair[1]}_{timestamp}.pkl'
# util.save_variable(model_file, model_list)

# %% [markdown]
# ##### Model inference, calculate p-val

# %%
model_file = project_dir + f'Output/jitter/coupling_network/session798911424_model_list_probeA_to_probeC_29_01_2023_144556.pkl'
model_list = util.load_variable(model_file)
print('num models', len(model_list))
# Out:
# num models 80

# %%
df_inference = model.pairwise_bivariate_regression_inference(model_list, filter_membership)
display(df_inference)

# timestamp = datetime.now().strftime('%d_%m_%Y_%H%M%S')
# output_file = project_dir + f'Output/jitter/coupling_network/df_inference_{probe_pair[0]}_to_{probe_pair[1]}_{timestamp}.parquet'
# df_inference.to_parquet(output_file)

df_inference.groupby(['source_probe', 'target_probe']).count()
# Out:
#                      pval   h source_probe target_probe source_area  \
# source    target
# 951092303 951102686   NaN NaN       probeA       probeC       VISam
# 951092369 951102686   NaN NaN       probeA       probeC       VISam
# 951092450 951102686   NaN NaN       probeA       probeC       VISam
# 951092488 951102686   NaN NaN       probeA       probeC       VISam
# 951092594 951102686   NaN NaN       probeA       probeC       VISam
# ...                   ...  ..          ...          ...         ...
# 951103958 951093795   NaN NaN       probeC       probeA        VISp
# 951103704 951093795   NaN NaN       probeC       probeA        VISp
# 951103877 951093795   NaN NaN       probeC       probeA        VISp
# 951103918 951093795   NaN NaN       probeC       probeA        VISp
# 951104192 951093795   NaN NaN       probeC       probeA        VISp
#
#                     target_area
# source    target
# 951092303 951102686        VISp
# 951092369 951102686        VISp
# 951092450 951102686        VISp
# 951092488 951102686        VISp
# 951092594 951102686        VISp
# ...                         ...
# 951103958 951093795       VISam
# 951103704 951093795       VISam
# 951103877 951093795       VISam
# 951103918 951093795       VISam
# 951104192 951093795       VISam
#
# [4944 rows x 6 columns]
#                            pval   h  source_area  target_area
# source_probe target_probe
# probeA       probeC          80  80          304          304
#              probeD           0   0          256          256
#              probeE           0   0          288          288
#              probeF           0   0          160          160
# probeC       probeA           0   0          304          304
#              probeD           0   0          304          304
#              probeE           0   0          342          342
#              probeF           0   0          190          190
# probeD       probeA           0   0          256          256
#              probeC           0   0          304          304
#              probeE           0   0          288          288
#              probeF           0   0          160          160
# probeE       probeA           0   0          288          288
#              probeC           0   0          342          342
#              probeD           0   0          288          288
#              probeF           0   0          180          180
# probeF       probeA           0   0          160          160
#              probeC           0   0          190          190
#              probeD           0   0          160          160
#              probeE           0   0          180          180

# %% [markdown]
# # Multiple hypothesis test.

# %%
# load all df_inference.
import glob
inference_dir = project_dir + 'Output/jitter/coupling_network/jitter_regression2/'
files = glob.glob(inference_dir + f'session798911424_df_inference_*.parquet')

df_inference_all = []
for f in files:
    dfx = pd.read_parquet(f)
    df_inference_all.append(dfx)

df_inference_all = pd.concat(df_inference_all, axis=0)
df_inference_all
# Out:
#                              pval         h source_probe target_probe  \
# source    target
# 951092303 951103361  2.184850e-01  0.591033       probeA       probeC
# 951092488 951103361  8.037977e-01 -0.107838       probeA       probeC
# 951092973 951103361  8.659755e-01 -0.078476       probeA       probeC
# 951092949 951103361  1.010961e-02  1.335128       probeA       probeC
# 951092940 951103361  1.189032e-02  0.938906       probeA       probeC
# ...                           ...       ...          ...          ...
# 951113039 951109435  1.050215e-10  0.529446       probeE       probeD
# 951113175 951109435  2.688843e-01  0.465418       probeE       probeD
# 951113271 951109435  7.719479e-05 -0.840776       probeE       probeD
# 951113211 951109435  9.240056e-01  0.038378       probeE       probeD
# 951113464 951109435  5.468932e-01 -0.218287       probeE       probeD
#
#                     source_area target_area
# source    target
# 951092303 951103361       VISam        VISp
# 951092488 951103361       VISam        VISp
# 951092973 951103361       VISam        VISp
# 951092949 951103361       VISam        VISp
# 951092940 951103361       VISam        VISp
# ...                         ...         ...
# 951113039 951109435       VISal        VISl
# 951113175 951109435       VISal        VISl
# 951113271 951109435       VISal        VISl
# 951113211 951109435       VISal        VISl
# 951113464 951109435       VISal        VISl
#
# [916 rows x 6 columns]

# %%
from statsmodels.stats.multitest import multipletests

test_outcome = multipletests(df_inference_all.pval.values.reshape(-1), alpha=0.01, method='bonferroni')  # fdr_by, bonferroni
df_inference_all['significant'] = test_outcome[0]
df_inference_all['h_sign'] = np.sign(df_inference_all.h)
print('adjusted p-value threshod', test_outcome[2])
display(df_inference_all.significant.value_counts())
# display(df_inference_all[df_inference_all.significant].h.value_counts(bins=[-1e10,0,1e10]))
display(df_inference_all[df_inference_all.significant].h_sign.value_counts())
# Out:
# adjusted p-value threshod 1.0971922180802451e-05
# False    769
# True     147
# Name: significant, dtype: int64
#  1.0    129
# -1.0     18
# Name: h_sign, dtype: int64

# %% [markdown]
# ##### hierarchy analysis.

# %%
bottom_up_pairs = list(itertools.combinations(area_hierarchy, 2))
top_down_pairs = list(itertools.combinations(reversed(area_hierarchy), 2))
df_inference_BU = model.select_plot_edges(df_inference_all, probe_pairs=bottom_up_pairs, select_ratio=1)
df_inference_TD = model.select_plot_edges(df_inference_all, probe_pairs=top_down_pairs, select_ratio=1)

BU_pairs = set(df_inference_BU[df_inference_BU.significant].index.values)
TD_pairs_flip = set([(y,x) for (x,y) in df_inference_TD[df_inference_TD.significant].index.values])
BU_TD_intersection = BU_pairs.intersection(TD_pairs_flip)

print(len(BU_pairs))
print(len(TD_pairs_flip))
print(len(BU_TD_intersection))

probe_graph = df_inference_all[df_inference_all.significant].groupby(['source_probe', 'target_probe'])[['significant']].count()
probe_graph_BU = df_inference_BU[df_inference_BU.significant].groupby(['source_probe', 'target_probe'])[['significant']].count()
probe_graph_TD = df_inference_TD[df_inference_TD.significant].groupby(['source_probe', 'target_probe'])[['significant']].count()

display(probe_graph); display(probe_graph_BU); display(probe_graph_TD)
# Out:
# edge stats:
#  False    386
# True      72
# Name: significant, dtype: int64
# (0.0, 10000000000.0]       66
# (-10000000000.001, 0.0]     6
# Name: h, dtype: int64
# edge stats:
#  False    383
# True      75
# Name: significant, dtype: int64
# (0.0, 10000000000.0]       63
# (-10000000000.001, 0.0]    12
# Name: h, dtype: int64
# 72
# 75
# 20
#                            significant
# source_probe target_probe
# probeA       probeC                  6
#              probeD                 20
#              probeE                 18
# probeC       probeA                 12
#              probeD                 19
#              probeE                 22
# probeD       probeA                  2
#              probeC                  8
#              probeE                 14
# probeE       probeA                  3
#              probeC                  9
#              probeD                 14
#                            significant
# source_probe target_probe
# probeC       probeA                 12
#              probeD                 19
#              probeE                 22
# probeD       probeA                  2
#              probeE                 14
# probeE       probeA                  3
#                            significant
# source_probe target_probe
# probeA       probeC                  6
#              probeD                 20
#              probeE                 18
# probeD       probeC                  8
# probeE       probeC                  9
#              probeD                 14

# %% [markdown]
# ##### connection strength
# hierarchy: V1, LM, RL, IP, AL, PM, AM

# %%
graph_probe_template = model.build_graph_probe_connection(probe_graph_BU, layout_probe=area_hierarchy, figure_path=None)
graph_probe_template = model.build_graph_probe_connection(probe_graph_TD, layout_probe=area_hierarchy, figure_path=None)
# Out:
# {'probeA': ['VISam'], 'probeB': ['VISam'], 'probeC': ['VISp'], 'probeD': ['VISl'], 'probeE': ['VISal'], 'probeF': ['VISrl']}
# {'probeA': ['VISam'], 'probeB': ['VISam'], 'probeC': ['VISp'], 'probeD': ['VISl'], 'probeE': ['VISal'], 'probeF': ['VISrl']}

# %% [markdown]
# ##### Check individual pair (optinal)

# %%
filter_membership_sub = filter_membership.loc[[(951108877, 951112590)]]
display(filter_membership_sub)
spike_times_x, spike_times_y = model.stack_spike_times_by_pairs_all(spike_times, filter_membership_sub, batch_size=None, verbose=False)
jittertool.spike_times_statistics(spike_times_y, trial_window[1], verbose=True)
jittertool.spike_times_statistics(spike_times_x, trial_window[1], verbose=True)

# %%
# model_par = {'filter_type': 'bspline', 'num_knots': 2, 'knot_space_par': 0.04, 'filter_length': 0.05, 'num_tail_drop': 1,
#              'append_nuisance': ['const', 'gaussian_kernel'], 'kernel_width': 0.08,
#              'const_offset': 0, 'learning_rate': 0.9, 'max_num_itrs': 60, 'epsilon': 1e-5}

# model_par = {'filter_type': 'square', 'filter_length': 0.04,
#              'append_nuisance': ['const', 'gaussian_kernel'], 'kernel_width': 0.08,
#              'const_offset': 0, 'learning_rate': 0.9, 'max_num_itrs': 60, 'epsilon': 1e-5}

# model_par = {'filter_type': 'bspline', 'num_knots': 3, 'knot_space_par': 0.04, 'filter_length': 0.05, 'num_tail_drop': 1,
#              'append_nuisance': ['const'], 'const_offset': 0, 'learning_rate': 0.9, 'max_num_itrs': 100, 'epsilon': 1e-5}

# model_par = {'filter_type': 'square', 'filter_length': 0.05,
#              'append_nuisance': ['const'], 'const_offset': 0, 'learning_rate': 0.9, 'max_num_itrs': 100, 'epsilon': 1e-5}

model_par_hat = jittertool.bivariate_continuous_time_coupling_filter_regression(
    spike_times_x[:], spike_times_y[:], trial_window, model_par, verbose=True)
jittertool.plot_continuous_time_bivariate_regression_model_par(model_par_hat, ylim=None)
# Out:
# num_trials 60
# X.shape (811, 2), basis_integral.shape (2, 1),beta.shape(2, 1)
#  53%|███████████████████████████████▊                            | 53/100 [00:00<00:00, 5315.47it/s]
# gradient [-0.00013346  0.00072144]
# num itr 53 [[-978.22343532]] 8.223355700831547e-06
# beta [ 8.44789209 -2.42597097]

# %% [markdown]
# # Plot all significant edges
# hierarchy: V1, LM, RL, IP, AL, PM, AM

# %%
# df_inference_all, df_inference_plot, active_units, selected_units
figure_path = project_dir + 'Output/fig/between_probe_network.pdf'
graph_template = model.build_graph_from_regression_pval(df_inference_all, layout_units=active_units,
    layout_probe=area_hierarchy, figure_path=figure_path)
# Out:
# num edges 147
# {'probeA': ['VISam'], 'probeB': ['VISam'], 'probeC': ['VISp'], 'probeD': ['VISl'], 'probeE': ['VISal'], 'probeF': ['VISrl']}
# Save figure to: D:/Brain_Network/Output/fig/between_probe_network.pdf

# %% [markdown]
# ##### plot subset: Select bottom-up, and top-down pairs, partial.

# %%
bottom_up_pairs = list(itertools.combinations(area_hierarchy, 2))
top_down_pairs = list(itertools.combinations(reversed(area_hierarchy), 2))
print(area_hierarchy)
print(list(bottom_up_pairs))
print(list(top_down_pairs))
# Out:
# ['probeC', 'probeD', 'probeF', 'probeE', 'probeA']
# [('probeC', 'probeD'), ('probeC', 'probeF'), ('probeC', 'probeE'), ('probeC', 'probeA'), ('probeD', 'probeF'), ('probeD', 'probeE'), ('probeD', 'probeA'), ('probeF', 'probeE'), ('probeF', 'probeA'), ('probeE', 'probeA')]
# [('probeA', 'probeE'), ('probeA', 'probeF'), ('probeA', 'probeD'), ('probeA', 'probeC'), ('probeE', 'probeF'), ('probeE', 'probeD'), ('probeE', 'probeC'), ('probeF', 'probeD'), ('probeF', 'probeC'), ('probeD', 'probeC')]

# %%
df_inference_plot = model.select_plot_edges(df_inference_all, probe_pairs=bottom_up_pairs, select_ratio=1)

figure_path = project_dir + 'Output/fig/between_probe_BU_network.pdf'
graph = model.build_graph_from_regression_pval(df_inference_plot, layout_units=active_units, layout_probe=area_hierarchy,
    graph_template=graph_template.copy(), figure_path=figure_path)
# Out:
# edge stats:
#  False    386
# True      72
# Name: significant, dtype: int64
# (0.0, 10000000000.0]       66
# (-10000000000.001, 0.0]     6
# Name: h, dtype: int64
# num edges 72
# {'probeA': ['VISam'], 'probeB': ['VISam'], 'probeC': ['VISp'], 'probeD': ['VISl'], 'probeE': ['VISal'], 'probeF': ['VISrl']}
# Save figure to: D:/Brain_Network/Output/fig/between_probe_BU_network.pdf

# %%
df_inference_plot = model.select_plot_edges(df_inference_all, probe_pairs=top_down_pairs, select_ratio=1)

figure_path = project_dir + 'Output/fig/between_probe_TD_network.pdf'
graph = model.build_graph_from_regression_pval(df_inference_plot, layout_units=active_units, layout_probe=area_hierarchy,
    graph_template=graph_template.copy(), figure_path=figure_path)
# Out:
# edge stats:
#  False    383
# True      75
# Name: significant, dtype: int64
# (0.0, 10000000000.0]       63
# (-10000000000.001, 0.0]    12
# Name: h, dtype: int64
# num edges 75
# {'probeA': ['VISam'], 'probeB': ['VISam'], 'probeC': ['VISp'], 'probeD': ['VISl'], 'probeE': ['VISal'], 'probeF': ['VISrl']}
# Save figure to: D:/Brain_Network/Output/fig/between_probe_TD_network.pdf

# %%
BU_pairs = set(df_inference_BU[df_inference_BU.significant].index.values)
TD_pairs_flip = set([(y,x) for (x,y) in df_inference_TD[df_inference_TD.significant].index.values])
BU_TD_intersection = BU_pairs.intersection(TD_pairs_flip)
BU_TD_intersection_flip = set([(y,x) for (x,y) in BU_TD_intersection])

# print(BU_pairs)
# print(TD_pairs_flip)
# print(BU_TD_intersection)

print(len(BU_pairs))
print(len(TD_pairs_flip))
print(len(BU_TD_intersection))

df_inference_plot = df_inference_all.loc[BU_TD_intersection.union(BU_TD_intersection_flip)]
df_inference_plot
# Out:
# 72
# 75
# 20
#                              pval         h source_probe target_probe  \
# source    target
# 951093608 951109282  0.000000e+00  4.580176       probeA       probeD
# 951109319 951103361  3.125451e-06 -1.639810       probeD       probeC
# 951109282 951093608  3.388608e-07 -2.073914       probeD       probeA
# 951103632 951093283  2.707296e-07  2.102633       probeC       probeA
# 951103332 951113039  5.980002e-07  1.634745       probeC       probeE
# 951103262 951112712  1.182312e-07  2.541114       probeC       probeE
# 951104192 951109319  0.000000e+00  3.242249       probeC       probeD
# 951112638 951109137  4.204910e-11 -3.557265       probeE       probeD
# 951092940 951103332  7.714718e-12  2.389659       probeA       probeC
# 951113039 951103332  6.374335e-09  2.177849       probeE       probeC
#           951109435  1.050215e-10  0.529446       probeE       probeD
# 951103332 951109319  0.000000e+00  4.028717       probeC       probeD
# 951109319 951113039  2.748323e-11 -2.550769       probeD       probeE
# 951109282 951112992  1.912978e-09 -2.325323       probeD       probeE
# 951109319 951103262  5.122187e-06 -1.843425       probeD       probeC
# 951103332 951092940  7.229356e-07  2.102646       probeC       probeA
# 951103958 951109319  1.526735e-09  3.511686       probeC       probeD
# 951103361 951109319  2.886580e-15  4.622106       probeC       probeD
# 951103262 951109319  2.912135e-09  2.951962       probeC       probeD
# 951112992 951109282  3.367982e-09  2.828409       probeE       probeD
# 951109137 951112638  2.499334e-12  2.809225       probeD       probeE
# 951109319 951103332  1.086883e-12 -2.340873       probeD       probeC
# 951112712 951103262  2.334476e-06 -2.125058       probeE       probeC
# 951103632 951092949  3.423093e-06  2.102514       probeC       probeA
# 951109319 951103632  6.594196e-09 -1.483095       probeD       probeC
# 951113039 951109319  2.220446e-16  4.711821       probeE       probeD
# 951092949 951103632  8.468691e-07  2.223704       probeA       probeC
# 951113464 951109282  4.884981e-15  4.213494       probeE       probeD
# 951109282 951113464  4.030158e-06 -1.836808       probeD       probeE
# 951093283 951103632  7.972897e-08 -2.142520       probeA       probeC
# 951109319 951103958  1.800835e-13 -1.909779       probeD       probeC
#           951093608  1.107445e-06 -1.665930       probeD       probeA
# 951103632 951109319  1.518903e-09  3.462280       probeC       probeD
# 951103958 951113271  0.000000e+00  6.181137       probeC       probeE
# 951109319 951104192  1.448422e-09 -2.827537       probeD       probeC
# 951109435 951113039  0.000000e+00  4.309712       probeD       probeE
# 951113271 951103958  8.023753e-06 -1.007197       probeE       probeC
# 951103332 951093283  2.833221e-08  1.669600       probeC       probeA
# 951093608 951109319  0.000000e+00  4.687892       probeA       probeD
# 951093283 951103332  8.958602e-08 -2.542619       probeA       probeC
#
#                     source_area target_area  significant
# source    target
# 951093608 951109282       VISam        VISl         True
# 951109319 951103361        VISl        VISp         True
# 951109282 951093608        VISl       VISam         True
# 951103632 951093283        VISp       VISam         True
# 951103332 951113039        VISp       VISal         True
# 951103262 951112712        VISp       VISal         True
# 951104192 951109319        VISp        VISl         True
# 951112638 951109137       VISal        VISl         True
# 951092940 951103332       VISam        VISp         True
# 951113039 951103332       VISal        VISp         True
#           951109435       VISal        VISl         True
# 951103332 951109319        VISp        VISl         True
# 951109319 951113039        VISl       VISal         True
# 951109282 951112992        VISl       VISal         True
# 951109319 951103262        VISl        VISp         True
# 951103332 951092940        VISp       VISam         True
# 951103958 951109319        VISp        VISl         True
# 951103361 951109319        VISp        VISl         True
# 951103262 951109319        VISp        VISl         True
# 951112992 951109282       VISal        VISl         True
# 951109137 951112638        VISl       VISal         True
# 951109319 951103332        VISl        VISp         True
# 951112712 951103262       VISal        VISp         True
# 951103632 951092949        VISp       VISam         True
# 951109319 951103632        VISl        VISp         True
# 951113039 951109319       VISal        VISl         True
# 951092949 951103632       VISam        VISp         True
# 951113464 951109282       VISal        VISl         True
# 951109282 951113464        VISl       VISal         True
# 951093283 951103632       VISam        VISp         True
# 951109319 951103958        VISl        VISp         True
#           951093608        VISl       VISam         True
# 951103632 951109319        VISp        VISl         True
# 951103958 951113271        VISp       VISal         True
# 951109319 951104192        VISl        VISp         True
# 951109435 951113039        VISl       VISal         True
# 951113271 951103958       VISal        VISp         True
# 951103332 951093283        VISp       VISam         True
# 951093608 951109319       VISam        VISl         True
# 951093283 951103332       VISam        VISp         True

# %%
df_inference_plot = df_inference_all.loc[BU_TD_intersection.union(BU_TD_intersection_flip)]

# df_inference_all, df_inference_plot, active_units, selected_units
figure_path = project_dir + 'Output/fig/between_probe_double_dir_network.pdf'
graph = model.build_graph_from_regression_pval(df_inference_plot, layout_units=active_units,
    layout_probe=area_hierarchy, graph_template=graph_template.copy(), figure_path=figure_path)
# Out:
# num edges 40
# {'probeA': ['VISam'], 'probeB': ['VISam'], 'probeC': ['VISp'], 'probeD': ['VISl'], 'probeE': ['VISal'], 'probeF': ['VISrl']}
# Save figure to: D:/Brain_Network/Output/fig/between_probe_double_dir_network.pdf

# %% [markdown]
# # KS test

# %%
model_id = 5

neuron_src, neuron_tgt = model_list[model_id][0]
print('neuron pair', neuron_src, neuron_tgt)

spike_times_x = spike_times.loc[neuron_src,:].tolist()[:20]
spike_times_y = spike_times.loc[neuron_tgt,:].tolist()[:20]

jittertool.spike_times_statistics(spike_times_x, trial_window[1], verbose=0)
jittertool.spike_times_statistics(spike_times_y, trial_window[1], verbose=0)

model_par = {'filter_type': 'square', 'filter_length': 0.04,
             'append_nuisance': ['const', 'gaussian_kernel'], 'kernel_width': 0.08,
             'const_offset': 0, 'learning_rate': 0.9, 'max_num_itrs': 60, 'epsilon': 1e-5}

model_hat = jittertool.bivariate_continuous_time_coupling_filter_regression(
    spike_times_x, spike_times_y, trial_window, model_par, mute_warning=True, verbose=True)

u_list = jittertool.ks_test(spike_times_x, spike_times_y, trial_window, model_list[model_id][1], dt=0.001, test_size=0.01, verbose=True)
u_list = jittertool.ks_test(spike_times_x, spike_times_y, trial_window, model_hat, dt=0.001, test_size=0.01, verbose=True)

model_par = {'filter_type': 'square', 'filter_length': 0.04, 'self_filter_type': 'square', 'self_filter_length': 0.04,
             'append_nuisance': ['const', 'gaussian_kernel'], 'kernel_width': 0.08,
             'const_offset': 0, 'learning_rate': 0.9, 'max_num_itrs': 100, 'epsilon': 1e-6}
model_hat = jittertool.bivariate_continuous_time_coupling_filter_full_regression(
    spike_times_x, spike_times_y, trial_window, model_par, verbose=True)
u_list = jittertool.ks_test_self_coupling(spike_times_x, spike_times_y, trial_window, model_hat, dt=0.0002, test_size=0.01, verbose=True)
# Out:
# neuron pair 951092303 951103632
# layers 2, nodes 1, trials 20
# meanFR 15.45	meanISI 20.016
# layers 2, nodes 1, trials 20
# meanFR 8.75	meanISI 26.244
# num_trials 20
# X.shape (350, 3), basis_integral.shape (3, 1),beta.shape(3, 1)
#  98%|███████████████████████████████████████████████████████████▉ | 59/60 [00:00<00:00, 6548.05it/s]
# gradient [-1.99936280e-05 -1.63866745e-03 -6.00891796e-05]
# num itr 59 [[-588.74648352]] 9.22046177687097e-06
# beta [10.93747017  0.62537684 -1.32019695]
# num_trials 20
# X.shape (350, 4), basis_integral.shape (4, 1),beta.shape(4, 1)
#  84%|██████████████████████████████████████████████████▍         | 84/100 [00:00<00:00, 8422.70it/s]
# gradient [-4.63988940e-07 -1.29566208e-05 -4.88366189e-07 -2.50317885e-06]
# num itr 84 [[-730.2019016]] 9.646161676091225e-07
# beta [10.9374988   0.2309576  -0.65533985 15.5919175 ]

# %%
model_file = project_dir + f'Output/jitter/coupling_network/session798911424_model_list_probeA_to_probeC_29_01_2023_144556.pkl'
model_list = util.load_variable(model_file)
print('num models', len(model_list))

# sub_trial_ids = spike_times.columns.values[50:70]
np.random.seed(99)
sub_trial_ids = np.random.choice(spike_times.columns.values, size=20, replace=False)
u_list_dict = model.ks_test_models_list(spike_times, trial_window, model_list, trial_ids=sub_trial_ids, verbose=False)
# Out:
# num models 80

# %%
figure_path = project_dir + f'Output/fig/test.pdf'

_=jitter.JitterTool.check_ks(np.hstack(u_list_dict.values()), test_size=0.01, bin_width=0.001, figure_path=figure_path, verbose=True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   This is separate from the ipykernel package so we can avoid doing imports until
# Save figure to: D:/Brain_Network/Output/fig/test.pdf

# %% [markdown]
# #### Plot all KS plots together.

# %%
model_dir = project_dir + 'Output/jitter/coupling_filter/CD_DE_condition19_joint_fit_fixed_portion_11122021/'
# file_path = model_dir + 'CD_ks_test_u_list_dict_x3_20211123_213246.pkl'
file_path = model_dir + 'CD_ks_test_u_list_dict_20211123_144356.pkl'
u_list_dict_0 = util.load_variable(file_path)
file_path = model_dir + 'DE_ks_test_u_list_dict_20211123_192039.pkl'
u_list_dict_1 = util.load_variable(file_path)
u_list_dict = z = {**u_list_dict_0, **u_list_dict_1}

# %%
file_path = project_dir + 'Output/fig/CD_DE_condition19_joint_fit_fixed_portion_11122021_KS.pdf'
model.plot_ks_u_list_dict(u_list_dict, test_size=0.01, file_path=file_path)
# Out:
# save figure: D:/Brain_Network/Output/fig/CD_DE_condition19_joint_fit_fixed_portion_11122021_KS.pdf

# %%
u_list = u_list_dict[(951108685, 951108867)]
u_list = u_list[u_list > 0]
CI_trap, mcdf, ecdf, CI_up, CI_dn = jitter.JitterTool.check_ks(u_list, test_size=0.01, bin_width=0.02, verbose=True)

# %% [markdown]
# ##### Debugging some errors.  951113075, 951113175 are weird. only one exception.
# 951109435 951113075
#
# 951108685 951113075
#
# 951108540 951113075

# %%
spike_times_x = spike_times.loc[951109319,:].tolist()
spike_times_y = spike_times.loc[951113717,:].tolist()
trial_length = trial_window[1]
jittertool.spike_times_statistics(spike_times_x, trial_length, verbose=True)
jittertool.spike_times_statistics(spike_times_y, trial_length, verbose=True)
# Out:
# layers 2, nodes 1, trials 285
# meanFR 27.144	meanISI 34.62
# layers 2, nodes 1, trials 285
# meanFR 7.358	meanISI 12.33

# %%
model_par = {'filter_type': 'square', 'filter_length': 0.05,
             'append_nuisance': ['const', 'gaussian_kernel'], 'kernel_width': 0.075,
             'const_offset': 0, 'learning_rate': 0.9, 'max_num_itrs': 100, 'epsilon': 1e-6}

# model_par = {'filter_type': 'none',
#              'append_nuisance': ['const', 'gaussian_kernel'], 'kernel_width': 0.08,
#              'const_offset': 0, 'learning_rate': 0.9, 'max_num_itrs': 100, 'epsilon': 1e-7}

# model_par = {'filter_type': 'none',
#              'append_nuisance': ['const',],
#              'const_offset': 0, 'learning_rate': 0.9, 'max_num_itrs': 100, 'epsilon': 1e-6}

# model_par = {'filter_type': 'bspline', 'num_knots': 5, 'knot_space_par': 0.1, 'filter_length': 0.4, 'num_tail_drop': 1,
#              'append_nuisance': ['const', 'gaussian_kernel'], 'kernel_width': 0.06,
#              'const_offset': 0, 'learning_rate': 0.9, 'max_num_itrs': 100, 'epsilon': 1e-5}

model_par_hat = jittertool.bivariate_continuous_time_coupling_filter_regression(
    spike_times_x[:], spike_times_y[:], [0, trial_length], model_par, verbose=True)
jittertool.plot_continuous_time_bivariate_regression_model_par(model_par_hat, ylim=[-10,10])
# Out:
# num_trials 285
# X.shape (4194, 3), basis_integral.shape (3, 1),beta.shape(3, 1)
#   9%|█████▍                                                       | 9/100 [00:00<00:00, 1288.66it/s]
# gradient [-3.23432971e-05 -5.28686735e-05 -6.55810746e-06]
# num itr 9 [[-6215.64457553]] 4.6153603358578543e-07
# beta [ 6.89122802  0.75076046 -0.10736803]

# %%
model_par_ks_test = jittertool.ks_test(spike_times_x, spike_times_y, trial_window, model_par_hat, dt=0.001, test_size=0.05, verbose=True)
